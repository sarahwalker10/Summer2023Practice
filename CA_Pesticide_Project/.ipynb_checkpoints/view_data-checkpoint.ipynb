# %% [markdown]
# I am using this file to view all of the (recommeded) data files in order to:
#
# 1. check that I can import without error
# 2. understand the information available to me (using the .head())

# %%
import geopandas as gpd
import pandas as pd

# %%
import os

# Get the list of all files available inside this file path
path = "/srv/data/my_shared_data_folder/cpr"
dir_list = os.listdir(path)
print(dir_list)
# Out:
# ['california_counties_census_data.csv', 'cleaned_county_data.csv', 'R13391251_SL140.csv', 'R13391250_SL050.csv', 'california_tracts.gpkg', 'pur2020_nonag.parquet', 'cleaned_tract_data.csv', 'cleaned_elsd_data.csv', 'california_zctas.gpkg', 'california_counties.gpkg', 'vision_providers_geocoded.csv', 'california_watersheds.gpkg', 'california_zcta_census_data.csv', 'R13391252_SL950.csv', 'new_test_file.gpkg', 'readme.md', 'california_elementary_school_districts.gpkg', 'pur2020_ag.parquet', 'california_tracts_census_data.csv', 'cleaned_zcta_data.csv', 'california_elementary_schools_census_data.csv', 'R13391293_SL860.csv', 'another_copy_pur2020_ag.parquet']

# %% [markdown]
# ## View Data

# %%
# california_counties.gpkg
# contains census county geographies for california.

counties = gpd.read_file("/srv/data/my_shared_data_folder/cpr/california_counties.gpkg")
counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD LSAD  \
# 0      06      091  00277310  06091         Sierra         Sierra County   06
# 1      06      067  00277298  06067     Sacramento     Sacramento County   06
# 2      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
# 3      06      009  01675885  06009      Calaveras      Calaveras County   06
# 4      06      111  00277320  06111        Ventura        Ventura County   06
#
#   CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND      AWATER  \
# 0      H1  G4020   NaN    NaN      NaN        A  2468694587    23299110
# 1      H1  G4020   472  40900      NaN        A  2499183617    76073827
# 2      H1  G4020   NaN  42200      NaN        A  7084000598  2729814515
# 3      H1  G4020   NaN    NaN      NaN        A  2641820834    43806026
# 4      H1  G4020   348  37100      NaN        A  4773390489   945942791
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# ...

# %%
# california_elementary_school_districts.gpkg
# contains Elementary School Divisions (ESLD) based on TIGER/Line geographies.

elem_districts = gpd.read_file("/srv/data/my_shared_data_folder/cpr/california_elementary_school_districts.gpkg")
elem_districts.head()
# Out:
#    Remaining STATEFP ELSDLEA    GEOID  \
# 0   0.651787      06   07840  0607840
# 1   1.000000      06   35010  0635010
# 2   1.000000      06   16080  0616080
# 3   1.000000      06   34050  0634050
# 4   1.000000      06   34080  0634080
#
#                                                 NAME LSAD LOGRADE HIGRADE  \
# 0                 Cayucos Elementary School District   00      KG      08
# 1  San Miguel Joint Union Elementary School District   00      KG      08
# 2        Greenfield Union Elementary School District   00      KG      08
# 3       San Antonio Union Elementary School District   00      KG      08
# 4          San Ardo Union Elementary School District   00      KG      08
#
#    MTFCC SDTYP FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0  G5400   NaN        E   129832824  73161315  +35.4785848  -120.8947455
# 1  G5400   NaN        E   461966792  18966669  +35.7840256  -120.8460414
# ...

# %%
# california_tracts.gpkg
# contains census tract geographies for California.

tracts = gpd.read_file("/srv/data/my_shared_data_folder/cpr/california_tracts.gpkg")
tracts.head()
# Out:
#   STATEFP COUNTYFP Geo_FIPS        GEOID    NAME            Geo_QNAME  MTFCC  \
# 0      06      079   010707  06079010707  107.07  Census Tract 107.07  G5020
# 1      06      079   010703  06079010703  107.03  Census Tract 107.03  G5020
# 2      06      079   010701  06079010701  107.01  Census Tract 107.01  G5020
# 3      06      079   010602  06079010602  106.02  Census Tract 106.02  G5020
# 4      06      079   010603  06079010603  106.03  Census Tract 106.03  G5020
#
#       ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0  14046662  10955892  +35.3320895  -120.8635035
# 1   4008527         0  +35.3185488  -120.8212247
# 2   2400673         0  +35.3270910  -120.8330760
# 3   5226755         0  +35.3575843  -120.8347297
# 4  10714762         0  +35.3741480  -120.8297440
#
#                                             geometry
# 0  MULTIPOLYGON (((-120.85931 35.31747, -120.8591...
# 1  MULTIPOLYGON (((-120.83326 35.32008, -120.8332...
# ...

# %%
# california_zctas.gpkg
# contains census zip code tabulation area geographies for California.

census_zipcodes = gpd.read_file("/srv/data/my_shared_data_folder/cpr/california_zctas.gpkg")
census_zipcodes.head()
# Out:
#   ZCTA5CE10 GEOID10 CLASSFP10 MTFCC10 FUNCSTAT10    ALAND10  AWATER10  \
# 0     93442   93442        B5   G6350          S  116211473   3827375
# 1     93402   93402        B5   G6350          S   75349658  10227041
# 2     93920   93920        B5   G6350          S  955396638  20975609
# 3     93452   93452        B5   G6350          S  295534633  17825056
# 4     93428   93428        B5   G6350          S  199437243   5071270
#
#     INTPTLAT10    INTPTLON10 STATEFP  TypeI  Geo_FIPS Geo_QName  \
# 0  +35.4019312  -120.7993662      11      3  93493442     93442
# 1  +35.2952317  -120.8354679      11      3  93493402     93402
# 2  +36.0928499  -121.5499954      11      3  93993920     93920
# 3  +35.7464854  -121.2233480      11      3  93493452     93452
# 4  +35.5849995  -121.0414745      11      3  93493428     93428
#
#                                             geometry
# 0  MULTIPOLYGON (((-120.80778 35.46444, -120.8059...
# ...

# %%
# california_watersheds.gpkg
# contains various river watersheds in California, via California Open Data.

watersheds = gpd.read_file("/srv/data/my_shared_data_folder/cpr/california_watersheds.gpkg")
watersheds.head()

# %%
# pur2020_ag.parquet
# contains agricultural PUR data for 2020, joined to the geographic boundaries.
# See https://calpip.cdpr.ca.gov/infodocs.cfm?page=columndefs (California's Department of Pesticide Regulation Data Dictionary) for more information.

#ag_pur = pd.read_parquet("/srv/data/my_shared_data_folder/cpr/pur2020_ag.parquet", engine = 'fastparquet')


# This data file proved to be large and difficult. 
# See the folder "importing_ag_data" for the work around to import this file

ag_pesticides = gpd.read_parquet("../CAPesticideResearch/importing_ag_data/ag_pesticides.parquet")

# %%
# pur2020_nonag.parquet
# contains non-agricultural (eg. Landscaping, golf courses) PUR data for 2020. 
# These PUR data are only recorded at the county level.

nonag_pur = pd.read_parquet("/srv/data/my_shared_data_folder/cpr/pur2020_nonag.parquet", engine = 'fastparquet')
nonag_pur.head()
# Out:
#     use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  lbs_prd_used  \
# 0  2891377   24341     2093.0          0.12      0.000375        0.3124
# 1  2891396   49224     5111.0          2.66      0.349024       13.1212
# 2  2891448   34240      486.0          3.20      0.015238        0.4762
# 3  2891059   64918     5331.0          0.60      0.020397        3.3995
# 4  2891007   67403     2094.0          1.00      0.007500        0.7500
#
#    amt_prd_used unit_of_meas  acre_planted  unit_planted  ...  document_no  \
# 0           6.0           OZ           NaN           NaN  ...          210
# 1         224.0           OZ           NaN           NaN  ...          229
# 2           9.0           OZ           NaN           NaN  ...          281
# 3        1542.0           GR           NaN           NaN  ...          433
# 4          12.0           OZ           NaN           NaN  ...          381
#
#   summary_cd  record_id comtrs  error_flag  chemalpha_cd  \
# ...

# %%
# cleaned_county_data.csv
# relevant census data at the county scale (cleaned)
# See cpr README for column descriptions in "Census Data Dictionary" 

census_counties = pd.read_csv("/srv/data/my_shared_data_folder/cpr/cleaned_county_data.csv")
census_counties.head()
# Out:
#    FIPS state  state_fips  county  tract         geoid         area_name  \
# 0  6001    ca           6       1    NaN  05000US06001    Alameda County
# 1  6003    ca           6       3    NaN  05000US06003     Alpine County
# 2  6005    ca           6       5    NaN  05000US06005     Amador County
# 3  6007    ca           6       7    NaN  05000US06007      Butte County
# 4  6009    ca           6       9    NaN  05000US06009  Calaveras County
#
#      area_land  total_pop  housing_units  ...  \
# 0   737.461875    1673133         617045  ...
# 1   738.340335       1344           1626  ...
# 2   594.584154      40095          18708  ...
# 3  1636.489658     217884          95047  ...
# 4  1020.019132      45349          27476  ...
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.055331
# 1                                 0.062937
# 2                                 0.043832
# 3                                 0.104909
# ...

# %%
# cleaned_elsd_data.csv
# relevant census data at the elementary school district scale (cleaned)
# See cpr README for column descriptions in "Census Data Dictionary" 

census_elemschools = pd.read_csv("/srv/data/my_shared_data_folder/cpr/cleaned_elsd_data.csv")
census_elemschools.head()

# %%
# cleaned_tract_data.csv
# relevant census data at the tract scale (cleaned)
# See cpr README for column descriptions in "Census Data Dictionary" 

census_tracts = pd.read_csv("/srv/data/my_shared_data_folder/cpr/cleaned_tract_data.csv")
census_tracts.head()
# Out:
#          FIPS state  state_fips  county   tract               geoid  \
# 0  6001400100    ca           6       1  400100  14000US06001400100
# 1  6001400200    ca           6       1  400200  14000US06001400200
# 2  6001400300    ca           6       1  400300  14000US06001400300
# 3  6001400400    ca           6       1  400400  14000US06001400400
# 4  6001400500    ca           6       1  400500  14000US06001400500
#
#            area_name  area_land  total_pop  housing_units  ...  \
# 0  Census Tract 4001   2.681810       3324           1478  ...
# 1  Census Tract 4002   0.226472       2038            908  ...
# 2  Census Tract 4003   0.428898       5449           2779  ...
# 3  Census Tract 4004   0.276502       4384           1986  ...
# 4  Census Tract 4005   0.228350       4048           1791  ...
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.000000
# 1                                 0.000000
# ...
